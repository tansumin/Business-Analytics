# %% [markdown]
# # Assignment 1
#
# This assignment is to test your understanding of Python basics.
#
# You won't need to upload/email your notebook, but you will be asked to provide your rationale as a part of your response. Rationales will count as 50% of the grade for each problem.
#
# Answer the questions and complete the tasks outlined below; use the specific method described, if applicable. In order to get complete points on your homework assigment you have to a) submit your rationale, b) based on your results answer the multiple choice questions on Blackboard.
#
# **Important note:** make sure you spend some time reviewing the basics of python notebooks under the folder 00-Python-Basics in the course repo or A Whirlwind Tour of Python.

# %% [markdown]
# # Question 1 & 2
# **What is 7 to the power of 9?**

# %%
# Your answer goes here
7**9
# Out:
# 40353607

# %% [markdown]
# # Question 3 & 4
#
# **What are the quotient and remainder of 45365/74?**

# %%
# Your answer goes here
quotient = 45365 // 74
remainder = 45365 % 74

print('Quotient of 45365/74:', quotient)
print('Remainder of 45365/74:', remainder)
# Out:
# Quotient of 45365/74: 613
# Remainder of 45365/74: 3

# %% [markdown]
# # Question 5 & 6
#
# Write a statement to check whether `a` is a multiple of 12 and within the range of [1000, 1800) or (0, 800].
#
# **What is the outcome of `a = 800`?**
#
# Note: (0, 800] represents a range from 0 to 800, where 0 is not included in the range, but 800 is.

# %%
a = 800

# %%
# Your answer goes here
(a%12 == 0) and ((1000<=a<1800) or (0<a<=800))
# Out:
# False

# %% [markdown]
# # Question 7
#
# **Given this nested list, what indexing yields to the word "hello"?**

# %%
lst = [[5,[100,200,{'target':[1,2,3,'hello']}],23,11],1,71,2,[3,4],'bye']
print(lst)
# Out:
# [[5, [100, 200, {'target': [1, 2, 3, 'hello']}], 23, 11], 1, 71, 2, [3, 4], 'bye']

# %%
# Your answer goes here
lst[0][1][2]['target'][3]
# Out:
# 'hello'

# %% [markdown]
# # Question 8 & 9
# Using a list comprehension, create a new list from list `L1` below, which contains only the absolute value of the even numbers from `L1` (using `abs()` function). Call this new list `L2`.
#
# **What is the sum of all of the elements of `L2`?**
#
# Hint: Use `sum(L2)` to get the sum of all the elements.

# %%
L1 = [64,  34, 112,  91,  62,  40, 117,  80,  96,  34,  48,  -9, -33,
      99,  16, 118, -51,  60, 115,   4, -10,  82,  -7,  77, -33, -40,
      77,  90,  -9,  52, -44,  25, -43,  28, -37,  92,  25, -45,   3,
      103,  22,  39, -52,  74, -54, -76, -10,   5, -54,  95, -59,  -2,
      110,  63, -53, 113, -43,  18,  49, -20,  81, -67,   1,  38, -24,
      57, -11, -69, -66, -67, -68, -16,  64, -34,  52, -37,  -7, -40,
      11,  -3,  76,  91, -57, -48, -10, -16,  14,  13, -65]

# %%
# Your answer goes here
L2 = [abs(x) for x in L1 if  x%2 == 0]
print(L2)
sum(L2)
# Out:
# [64, 34, 112, 62, 40, 80, 96, 34, 48, 16, 118, 60, 4, 10, 82, 40, 90, 52, 44, 28, 92, 22, 52, 74, 54, 76, 10, 54, 2, 110, 18, 20, 38, 24, 66, 68, 16, 64, 34, 52, 40, 76, 48, 10, 16, 14]
# 2264

# %% [markdown]
# # Question 10 & 11
#
# Write a **function** that receives a list of integer numbers and returns a list of numbers that are multiples of 4. Call this function `mult4_filter()`.
#
# **Given the list `L3` below, how many elements does the outcome of `mult4_filter(L3)` have?**
#
# Hint: use `len(mult4_filter(L3))` to get the number of elements.

# %%
L3 = [15, 11,  1,  3, 13,  3, 14, 16, 17, 17,  6, 18, 10, 19,  8,  1, 18,
      17, 14,  1,  5,  2, 13,  0,  1, 13, 16,  8,  5, 11, 12,  8, 17, 14,
      10, 18, 17, 16,  3,  7,  8, 15, 18,  7, 10,  5,  7, 16,  6,  5, 24,
      18, 22, 32]

# %%
# Your answer goes here
def mult4_filter(L):
    # Your code goes here
    return [x for x in L if x%4==0]

len(mult4_filter(L3))
# Out:
# 12
